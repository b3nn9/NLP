# %% [markdown]
# - 일괄변환보다는 년도별 변환이 유리
# - 코드 안정화 조치 필요

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
# 3.x에서는
# from cStringIO import StringIO
from io import StringIO

import time
import os
import shutil

import pandas as pd
import numpy as np

# %%
import pdfminer
pdfminer.__version__
# Out:
# '20170720'

# %%
def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()
    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)
    fp.close()
    device.close()
    str = retstr.getvalue()
    with open(path.replace('.pdf','.txt'),'w') as file:
        file.write(str)
    retstr.close()
    print(path.split('/')[-1],'텍스트 파일로 변환하였습니다.')
    return str

# %%
pdfFullPath = r'./IAIA_Proceedings/'

if os.path.isdir(pdfFullPath) != True:print('경로가 존재하지 않습니다.')
    
proceedingsList = os.listdir(pdfFullPath)
proceedingsList.sort()

# print(proceedingsList)

for procdYear in proceedingsList:
    if procdYear[:2] == '20':
        print(procdYear,"년 작업중입니다.")
        paperFullPath = pdfFullPath+procdYear+'/Paper/'
        paperList = os.listdir(paperFullPath)
        paperList.sort()
        
        for paper in paperList:
            if paper.find('.pdf') != -1: convert_pdf_to_txt(paperFullPath+paper)
# Out:
# 2011 년 작업중입니다.
# 113 Expectation on Railway Expansion in Hong Kong.pdf 텍스트 파일로 변환하였습니다.
# Agriculture Environmental Assessment and Certification, Yukon, Canada.pdf 텍스트 파일로 변환하였습니다.
# Application of Environmental Quality Objectives in Regional Scale Infrastructure Projects, a Swedish Example.pdf 텍스트 파일로 변환하였습니다.
# Archaeological Predictive Models for ESIA Baseline.pdf 텍스트 파일로 변환하였습니다.
# Assessing Support for Emissions Reduction Policy.pdf 텍스트 파일로 변환하였습니다.
# Assessment Guidelines, Oil and Gas Exploration.pdf 텍스트 파일로 변환하였습니다.
# Best Practices in Small Hydro Development.pdf 텍스트 파일로 변환하였습니다.
# Between Legality and Legitimacy of Public Involvement in Environmental Decision Making.pdf 텍스트 파일로 변환하였습니다.
# Biodiversity Offsets and ESIA Schedules.pdf 텍스트 파일로 변환하였습니다.
# By_Spanish_road_compensatory_final.pdf 텍스트 파일로 변환하였습니다.
# CSR, Global Change, Adaptation and Stakeholders.pdf 텍스트 파일로 변환하였습니다.
# Cancun Beach Nourishment Environmental Effects.pdf 텍스트 파일로 변환하였습니다.
# ...

# %%
pdfFullPath = r'./IAIA_Proceedings/'

if os.path.isdir(pdfFullPath) != True:print('경로가 존재하지 않습니다.')
    
proceedingsList = os.listdir(pdfFullPath)
proceedingsList.sort()

# print(proceedingsList)

for procdYear in proceedingsList:
    if procdYear[:4] == '2016':
        print(procdYear,"년 작업중입니다.")
        paperFullPath = pdfFullPath+procdYear+'/Paper/'
        paperList = os.listdir(paperFullPath)
        paperList.sort()
        
        for paper in paperList:
            if paper.find('.pdf') != -1: convert_pdf_to_txt(paperFullPath+paper)
# Out:
# 2016 년 작업중입니다.
# Abou Ibrahim, Assem - Resilience in Lebanon.pdf 텍스트 파일로 변환하였습니다.
# Adekoya, Adebanji - Managing Non-Technical Risk in E and P Projects.pdf 텍스트 파일로 변환하였습니다.
# Adusei-Asante, Kwadwo - IA of University-Free Deregulation, Western Australia.pdf 텍스트 파일로 변환하였습니다.
# Adusei-Asante, Kwadwo - Policies with the SIA Framework.pdf 텍스트 파일로 변환하였습니다.
# Ahmed, Tanvir - Environmental Burden of Tanneries in Bangladesh.pdf 텍스트 파일로 변환하였습니다.
# Ahmed, Tanvir - Evaluation of the EIA System in Bangladesh.pdf 텍스트 파일로 변환하였습니다.
# Aizawa, Hirofumi - EIA Technical Guidance on Radioactive Materials.pdf 텍스트 파일로 변환하였습니다.
# Albayrak, Ali - Public Behavior for Public Participation in EIA Process, Turkey.pdf 텍스트 파일로 변환하였습니다.
# Albayrak, Ali - Required Actions for EIA Regulation in Turkey.pdf 텍스트 파일로 변환하였습니다.
# Barasa, Philip - SEA for Energy Sector, Kenya.pdf 텍스트 파일로 변환하였습니다.
# Baresi, Umberto - SEA Integration in Sustainable Planning Frameworks.pdf 텍스트 파일로 변환하였습니다.
# ...

# %%
pdfFullPath = r'./IAIA_Proceedings/'

if os.path.isdir(pdfFullPath) != True:print('경로가 존재하지 않습니다.')
    
proceedingsList = os.listdir(pdfFullPath)
proceedingsList.sort()

# print(proceedingsList)

for procdYear in proceedingsList:
    if procdYear[:4] == '2017':
        print(procdYear,"년 작업중입니다.")
        paperFullPath = pdfFullPath+procdYear+'/Paper/'
        paperList = os.listdir(paperFullPath)
        paperList.sort()
        
        for paper in paperList:
            if paper.find('.pdf') != -1: convert_pdf_to_txt(paperFullPath+paper)
# Out:
# 2017 년 작업중입니다.
# Adusei-Asante, Kwadwo - On the Brink of Politicisation, Public Policy IA Practice.pdf 텍스트 파일로 변환하였습니다.
# Adusei-Asante, Kwadwo - Towards Developing Policy Impact Assessment Framework.pdf 텍스트 파일로 변환하였습니다.
# Amaya, Andres - Social Dynamics Prevent 400 MW Hydropower-Porce IV.pdf 텍스트 파일로 변환하였습니다.
# Andrade, Andre - Reasons to Approve Hydropower Projects in Brazil.pdf 텍스트 파일로 변환하였습니다.
# Baldwin, Gunnar - ECE, Sound Foundation for Sustainable Development.pdf 텍스트 파일로 변환하였습니다.
# Blair, Chris - Eel River Dam Removal Project EA and Follow-up.pdf 텍스트 파일로 변환하였습니다.
# Bohlken, Frank - Socio-Economic Effects Management, British Columbia, Canada.pdf 텍스트 파일로 변환하였습니다.
# Brownlie, Susie - Offsets, Guiding Practice in Russia's Energy Sector.pdf 텍스트 파일로 변환하였습니다.
# Cape, Lydia - Scenarios-Based Risk Model for Shale Gas Scientific Assessment.pdf 텍스트 파일로 변환하였습니다.
# Carthew, Ruari - Using Resilience to Offset Cumulative Impacts.pdf 텍스트 파일로 변환하였습니다.
# ...

# %%
pdfFullPath = r'./IAIA_Proceedings/'

if os.path.isdir(pdfFullPath) != True:print('경로가 존재하지 않습니다.')
    
proceedingsList = os.listdir(pdfFullPath)
proceedingsList.sort()

# print(proceedingsList)

for procdYear in proceedingsList:
    if procdYear[:4] == '2012':
        print(procdYear,"년 작업중입니다.")
        paperFullPath = pdfFullPath+procdYear+'/Paper/'
        paperList = os.listdir(paperFullPath)
        paperList.sort()
        
        for paper in paperList:
#             0바이트 체크 필요
            if paper.find('.pdf') != -1: convert_pdf_to_txt(paperFullPath+paper)
# Out:
# 2012 년 작업중입니다.
# Patiri, Victor .  PORT OF AC%cc%a7U, BRAZIL LIGHT POLLUTION MITIGATION.pdf 텍스트 파일로 변환하였습니다.
# Pavasars, Ivars.  SEA in Latvian rural spatial planning.pdf 텍스트 파일로 변환하였습니다.
# Peirson-Smith, Timothy.  Embracing Social Media to Enhance Public Participation.pdf 텍스트 파일로 변환하였습니다.
# Pereira, Margaret.  Long term monitoring of a Waste-to-Energy facility in Porto.pdf 텍스트 파일로 변환하였습니다.
# Petrova, Svetla.  Social impacts of mining at a local community level and the role of CSR for sustainability.pdf 텍스트 파일로 변환하였습니다.
# Pigeon, Jean-Luc.  Preliminary Environmental assessments for four French offshore wind farms.pdf 텍스트 파일로 변환하였습니다.
# Pirillo, Ernesto.  The Need for SEA of Metal Mining in Argentina.pdf 텍스트 파일로 변환하였습니다.
# Pokhrel, Sumit.  Internalizing the Externalities, SEA Viet Nam.pdf 텍스트 파일로 변환하였습니다.
# Polido, Alexandra.  SEA profile of small islands states and territories.pdf 텍스트 파일로 변환하였습니다.
# ...
